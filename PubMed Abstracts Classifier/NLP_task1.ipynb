# %% [raw]
# Problem: Classify given set of Pubmed abstracts (biomedical literature abstracts) into four classes:
# a) Abstracts containing Drug adverse events (D064420)
# b) Abstracts containing Congenital anomalies (D000013)
# c) Abstracts containing congenital anomalies caused by drug usage.
# d) Others

# %% [markdown]
# ### Task 1: Write a Python program to download at most 10,000 abstracts (in either XML format or just the plain text abstracts) using Entrez utilities belonging to each of the four classes given at the top of the page.

# %%
pip install entrezpy --user
# Out:
# Requirement already satisfied: entrezpy in c:\users\lenovo\appdata\roaming\python\python38\site-packages (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install biopython
# Out:
# Requirement already satisfied: biopython in c:\users\lenovo\anaconda3\lib\site-packages (1.78)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from biopython) (1.18.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Using entrezpy

# %%
import entrezpy.conduit
import entrezpy.base.result
import entrezpy.base.analyzer

# %%
c = entrezpy.conduit.Conduit('adistar121999@gmail.com')
fetch_pubmed = c.new_pipeline()
fetch_pubmed.add_fetch({'db':'pubmed', 'id':['D064420'], 'retmode':'xml'})
c.run(fetch_pubmed)
# Out:
# <?xml version="1.0" ?>
# <!DOCTYPE PubmedArticleSet PUBLIC "-//NLM//DTD PubMedArticle, 1st January 2019//EN" "https://dtd.nlm.nih.gov/ncbi/pubmed/out/pubmed_190101.dtd">
# <PubmedArticleSet>
# <PubmedArticle>
#     <MedlineCitation Status="MEDLINE" Owner="NLM">
#         <PMID Version="1">64420</PMID>
#         <DateCompleted>
#             <Year>1977</Year>
#             <Month>03</Month>
#             <Day>31</Day>
#         </DateCompleted>
#         <DateRevised>
#             <Year>2013</Year>
#             <Month>11</Month>
#             <Day>21</Day>
#         </DateRevised>
#         <Article PubModel="Print">
#             <Journal>
#                 <ISSN IssnType="Print">0323-4347</ISSN>
#                 <JournalIssue CitedMedium="Print">
#                     <Volume>103</Volume>
#                     <Issue>6</Issue>
#                     <PubDate>
#                         <Year>1976</Year>
#                     </PubDate>
#                 </JournalIssue>
#                 <Title>Folia haematologica (Leipzig, Germany : 1928)</Title>
#                 <ISOAbbreviation>Folia Haematol Int Mag Klin Morphol Blutforsch</ISOAbbreviation>
#             </Journal>
#             <ArticleTitle>[Congenital and acquired variants of plasma fibrinogen].</ArticleTitle>
#             <Pagination>
#                 <MedlinePgn>793-806</MedlinePgn>
#             </Pagination>
#             <AuthorList CompleteYN="Y">
#                 <Author ValidYN="Y">
#                     <LastName>Krantz</LastName>
#                     <ForeName>S</ForeName>
#                     <Initials>S</Initials>
#                 </Author>
#                 <Author ValidYN="Y">
#                     <LastName>Lober</LastName>
#                     <ForeName>M</ForeName>
#                     <Initials>M</Initials>
#                 </Author>
#             </AuthorList>
#             <Language>ger</Language>
#             <PublicationTypeList>
#                 <PublicationType UI="D004740">English Abstract</PublicationType>
#                 <PublicationType UI="D016428">Journal Article</PublicationType>
#                 <PublicationType UI="D016454">Review</PublicationType>
#             </PublicationTypeList>
#             <VernacularTitle>Ubersicht Angeborene und erworbene Varianten des Plasmafibrinogens</VernacularTitle>
#         </Article>
#         <MedlineJournalInfo>
#             <Country>Germany</Country>
#             <MedlineTA>Folia Haematol Int Mag Klin Morphol Blutforsch</MedlineTA>
#             <NlmUniqueID>0374615</NlmUniqueID>
#             <ISSNLinking>0323-4347</ISSNLinking>
#         </MedlineJournalInfo>
#         <ChemicalList>
#             <Chemical>
#                 <RegistryNumber>3G0H8C9362</RegistryNumber>
#                 <NameOfSubstance UI="D003035">Cobalt</NameOfSubstance>
#             </Chemical>
#             <Chemical>
#                 <RegistryNumber>9001-32-5</RegistryNumber>
#                 <NameOfSubstance UI="D005340">Fibrinogen</NameOfSubstance>
#             </Chemical>
#         </ChemicalList>
#         <CitationSubset>IM</CitationSubset>
#         <MeshHeadingList>
#             <MeshHeading>
#                 <DescriptorName UI="D001778" MajorTopicYN="N">Blood Coagulation Disorders</DescriptorName>
#                 <QualifierName UI="Q000209" MajorTopicYN="N">etiology</QualifierName>
#             </MeshHeading>
#             <MeshHeading>
#                 <DescriptorName UI="D003035" MajorTopicYN="N">Cobalt</DescriptorName>
#                 <QualifierName UI="Q000494" MajorTopicYN="N">pharmacology</QualifierName>
#             </MeshHeading>
#             <MeshHeading>
#                 <DescriptorName UI="D005312" MajorTopicYN="N">Fetal Blood</DescriptorName>
#             </MeshHeading>
#             <MeshHeading>
#                 <DescriptorName UI="D005340" MajorTopicYN="Y">Fibrinogen</DescriptorName>
#             </MeshHeading>
#             <MeshHeading>
#                 <DescriptorName UI="D014644" MajorTopicYN="N">Genetic Variation</DescriptorName>
#             </MeshHeading>
#             <MeshHeading>
#                 <DescriptorName UI="D006505" MajorTopicYN="N">Hepatitis</DescriptorName>
#                 <QualifierName UI="Q000378" MajorTopicYN="N">metabolism</QualifierName>
#             </MeshHeading>
#             <MeshHeading>
#                 <DescriptorName UI="D008113" MajorTopicYN="N">Liver Neoplasms</DescriptorName>
#                 <QualifierName UI="Q000378" MajorTopicYN="N">metabolism</QualifierName>
#             </MeshHeading>
#         </MeshHeadingList>
#         <NumberOfReferences>89</NumberOfReferences>
#     </MedlineCitation>
#     <PubmedData>
#         <History>
#             <PubMedPubDate PubStatus="pubmed">
#                 <Year>1976</Year>
#                 <Month>1</Month>
#                 <Day>1</Day>
#             </PubMedPubDate>
#             <PubMedPubDate PubStatus="medline">
#                 <Year>1976</Year>
#                 <Month>1</Month>
#                 <Day>1</Day>
#                 <Hour>0</Hour>
#                 <Minute>1</Minute>
#             </PubMedPubDate>
#             <PubMedPubDate PubStatus="entrez">
#                 <Year>1976</Year>
#                 <Month>1</Month>
#                 <Day>1</Day>
#                 <Hour>0</Hour>
#                 <Minute>0</Minute>
#             </PubMedPubDate>
#         </History>
#         <PublicationStatus>ppublish</PublicationStatus>
#         <ArticleIdList>
#             <ArticleId IdType="pubmed">64420</ArticleId>
#         </ArticleIdList>
#     </PubmedData>
# </PubmedArticle>
#
# </PubmedArticleSet>

# %% [markdown]
# #### Using Bio

# %%
from Bio import Entrez
import pandas as pd
import numpy as np
import os

# %%
def search(query):
    Entrez.email = 'adistar121999@gmail.com'
    handle = Entrez.esearch(db='pubmed',
                            sort='relevance',
                            retmax='1000',
                            retmode='xml',
                            term=query)
    results = Entrez.read(handle)
    return results

# %%
def fetch_details(id_list):
    ids = ','.join(id_list)
    Entrez.email = 'adistar121999@gmail.com'
    handle = Entrez.efetch(db='pubmed',
                           retmode='xml',
                           id=ids)
    results = Entrez.read(handle)
    return results

# %%
results = search('Drug-Related Side Effects and Adverse Reactions')
id_list = results['IdList']
papers = fetch_details(id_list)

# %%
import json
print(json.dumps(papers['PubmedArticle'][0], indent=2))
# Out:
# {
#   "MedlineCitation": {
#     "SpaceFlightMission": [],
#     "KeywordList": [
#       [
#         "adverse drug reaction",
#         "allergy",
#         "chondroitin",
#         "glucosamine",
#         "osteoarthritis"
#       ]
#     ],
#     "GeneralNote": [],
#     "OtherAbstract": [],
#     "CitationSubset": [
#       "IM"
#     ],
#     "OtherID": [],
#     "PMID": "31597786",
#     "DateCompleted": {
#       "Year": "2021",
#       "Month": "01",
#       "Day": "18"
#     },
#     "DateRevised": {
#       "Year": "2021",
#       "Month": "01",
#       "Day": "18"
#     },
#     "Article": {
#       "Language": [
#         "eng"
#       ],
#       "ELocationID": [
#         "10.1136/postgradmedj-2019-136957"
#       ],
#       "ArticleDate": [
#         {
#           "Year": "2019",
#           "Month": "10",
#           "Day": "09"
#         }
#       ],
#       "Journal": {
#         "ISSN": "1469-0756",
#         "JournalIssue": {
#           "Volume": "96",
#           "Issue": "1134",
#           "PubDate": {
#             "Year": "2020",
#             "Month": "Apr"
#           }
#         },
#         "Title": "Postgraduate medical journal",
#         "ISOAbbreviation": "Postgrad Med J"
#       },
#       "ArticleTitle": "Hypersensitive adverse drug reactions to glucosamine and chondroitin preparations in Australia between 2000 and 2011.",
#       "Pagination": {
#         "MedlinePgn": "190-193"
#       },
#       "Abstract": {
#         "AbstractText": [
#           "This study investigates spontaneous adverse drug reactions (ADRs) to glucosamine and chondroitin in the Australian population between 2000 and 2011, with a primary focus on hypersensitivity reactions.",
#           "Case reports of ADR to glucosamine and chondroitin sent to the Therapeutic Goods Administration between 2000 and 2011 were obtained and analysed. The demographic information and severity of the ADR were recorded for individual ADR cases. These reactions were classified according to the Brown <i>et al</i> grading system for generalised hypersensitivity reactions. This included mild hypersensitivity reactions (generalised erythema, urticaria and angioedema) through to moderate hypersensitivity reactions (wheeze, nausea, vomiting, dizziness (presyncope), diaphoresis, chest or throat tightness and abdominal pain), and more severe reactions (hypotension, confusion and collapse).",
#           "In this study of 366 ADRs to glucosamine and chondroitin preparations, 71.85% of cases (n=263) were found to have hypersensitivity reactions. Of these 263 cases, 92 cases were classified as mild (eg, pruritus, urticaria and lip oedema), 128 cases classified as moderate (such as dyspnoea, nausea and abdominal pain), and 43 cases classified as severe (including amnesia, gait disturbance, somnolence and hypotension). It is not clear whether the patients involved had a known shellfish allergy or underlying atopy.",
#           "Results of this investigation support the need for clear labelling on glucosamine and chondroitin preparations to raise awareness of possible adverse events for those predisposed to allergy or atopy in response to shellfish."
#         ],
#         "CopyrightInformation": "\u00a9 Author(s) (or their employer(s)) 2020. No commercial re-use. See rights and permissions. Published by BMJ."
#       },
#       "AuthorList": [
#         {
#           "Identifier": [
#             "http://orcid.org/0000-0002-7027-5558"
#           ],
#           "AffiliationInfo": [
#             {
#               "Identifier": [],
#               "Affiliation": "Pharmacology, The University of Adelaide, Adelaide, South Australia, Australia claire.hoban@adelaide.edu.au."
#             }
#           ],
#           "LastName": "Hoban",
#           "ForeName": "Claire",
#           "Initials": "C"
#         },
#         {
#           "Identifier": [],
#           "AffiliationInfo": [
#             {
#               "Identifier": [],
#               "Affiliation": "Anatomy and Pathology, The University of Adelaide, Adelaide, South Australia, Australia."
#             }
#           ],
#           "LastName": "Byard",
#           "ForeName": "Roger",
#           "Initials": "R"
#         },
#         {
#           "Identifier": [],
#           "AffiliationInfo": [
#             {
#               "Identifier": [],
#               "Affiliation": "Pharmacology, The University of Adelaide, Adelaide, South Australia, Australia."
#             }
#           ],
#           "LastName": "Musgrave",
#           "ForeName": "Ian",
#           "Initials": "I"
#         }
#       ],
#       "PublicationTypeList": [
#         "Journal Article"
#       ]
#     },
#     "MedlineJournalInfo": {
#       "Country": "England",
#       "MedlineTA": "Postgrad Med J",
#       "NlmUniqueID": "0234135",
#       "ISSNLinking": "0032-5473"
#     },
#     "ChemicalList": [
#       {
#         "RegistryNumber": "0",
#         "NameOfSubstance": "Analgesics"
#       },
#       {
#         "RegistryNumber": "0",
#         "NameOfSubstance": "Nonprescription Drugs"
#       },
#       {
#         "RegistryNumber": "9007-27-6",
#         "NameOfSubstance": "Chondroitin"
#       },
#       {
#         "RegistryNumber": "N08U5BOQ1K",
#         "NameOfSubstance": "Glucosamine"
#       }
#     ],
#     "MeshHeadingList": [
#       {
#         "QualifierName": [
#           "adverse effects",
#           "therapeutic use"
#         ],
#         "DescriptorName": "Analgesics"
#       },
#       {
#         "QualifierName": [
#           "epidemiology"
#         ],
#         "DescriptorName": "Australia"
#       },
#       {
#         "QualifierName": [
#           "adverse effects",
#           "therapeutic use"
#         ],
#         "DescriptorName": "Chondroitin"
#       },
#       {
#         "QualifierName": [
#           "diagnosis",
#           "epidemiology",
#           "etiology",
#           "physiopathology"
#         ],
#         "DescriptorName": "Drug Hypersensitivity"
#       },
#       {
#         "QualifierName": [
#           "methods",
#           "standards"
#         ],
#         "DescriptorName": "Drug Labeling"
#       },
#       {
#         "QualifierName": [
#           "diagnosis",
#           "epidemiology",
#           "etiology",
#           "physiopathology"
#         ],
#         "DescriptorName": "Drug-Related Side Effects and Adverse Reactions"
#       },
#       {
#         "QualifierName": [],
#         "DescriptorName": "Female"
#       },
#       {
#         "QualifierName": [
#           "adverse effects",
#           "therapeutic use"
#         ],
#         "DescriptorName": "Glucosamine"
#       },
#       {
#         "QualifierName": [],
#         "DescriptorName": "Humans"
#       },
#       {
#         "QualifierName": [],
#         "DescriptorName": "Male"
#       },
#       {
#         "QualifierName": [],
#         "DescriptorName": "Middle Aged"
#       },
#       {
#         "QualifierName": [],
#         "DescriptorName": "Needs Assessment"
#       },
#       {
#         "QualifierName": [
#           "adverse effects",
#           "therapeutic use"
#         ],
#         "DescriptorName": "Nonprescription Drugs"
#       },
#       {
#         "QualifierName": [
#           "drug therapy",
#           "epidemiology"
#         ],
#         "DescriptorName": "Osteoarthritis"
#       }
#     ],
#     "CoiStatement": "Competing interests: None declared."
#   },
#   "PubmedData": {
#     "ReferenceList": [],
#     "History": [
#       {
#         "Year": "2019",
#         "Month": "07",
#         "Day": "17"
#       },
#       {
#         "Year": "2019",
#         "Month": "09",
#         "Day": "17"
#       },
#       {
#         "Year": "2019",
#         "Month": "09",
#         "Day": "30"
#       },
#       {
#         "Year": "2019",
#         "Month": "10",
#         "Day": "11",
#         "Hour": "6",
#         "Minute": "0"
#       },
#       {
#         "Year": "2021",
#         "Month": "1",
#         "Day": "20",
#         "Hour": "6",
#         "Minute": "0"
#       },
#       {
#         "Year": "2019",
#         "Month": "10",
#         "Day": "11",
#         "Hour": "6",
#         "Minute": "0"
#       }
#     ],
#     "PublicationStatus": "ppublish",
#     "ArticleIdList": [
#       "31597786",
#       "postgradmedj-2019-136957",
#       "10.1136/postgradmedj-2019-136957"
#     ]
#   }
# }

# %%
df_fin = pd.DataFrame(columns=['pmid','title','key words','abstract'])
for paper in papers['PubmedArticle'][:20]:
    klist,abstract='',''
    pmid = paper['MedlineCitation']['PMID']
    title = paper['MedlineCitation']['Article']['ArticleTitle']
    if paper['MedlineCitation']['KeywordList']:
        for k in paper['MedlineCitation']['KeywordList'][0]:
            klist=klist+k+' '
        klist = klist.split(' ')[:-1]
    else:
        klist = []
    for t in paper['MedlineCitation']['Article']['Abstract']['AbstractText']:
        abstract+=t
    df = pd.DataFrame({'pmid':pmid,'title':title,'key words':[klist],'abstract':abstract})
    df_fin = df_fin.append(df,ignore_index=True)
df_fin['Label'] = 'adverse drug'
df_fin.head()
# Out:
#        pmid                                              title  \
# 0  31597786  Hypersensitive adverse drug reactions to gluco...
# 1  31056713  Impact of protocol change on individual factor...
# 2  31771857                            Adverse drug reactions.
# 3  32249738  Adverse Drug Reactions in Canada (2009-2018): ...
# 4  30833488  Adverse Drug Reactions in an Oncological Popul...
#
#                                            key words  \
# 0  [adverse, drug, reaction, allergy, chondroitin...
# 1  [Adverse, reactions, Breast, cancer, Chemother...
# 2  [Adverse, drug, reaction, Drug, safety, Efecto...
# 3                                                 []
# 4  [Adverse, drug, reactions, Clinical, oncology,...
#
#                                             abstract         Label
# 0  This study investigates spontaneous adverse dr...  adverse drug
# 1  Asthenia, myalgia, arthralgia, mucositis, abdo...  adverse drug
# 2  An adverse drug reaction (ADR) is defined as a...  adverse drug
# 3  Annually, thousands of individuals die and ten...  adverse drug
# 4  Our goal was to determine (a) the prevalence o...  adverse drug

# %%
def create_df(query,label):
    
    results = search(query)
    id_list = results['IdList']
    papers = fetch_details(id_list)
    
    df_fin = pd.DataFrame(columns=['pmid','title','key words','abstract'])
    
    
    for paper in papers['PubmedArticle']:
        if 'Abstract' in paper['MedlineCitation']['Article'].keys():
            klist,abstract='',''
        
            pmid = paper['MedlineCitation']['PMID']
        
            title = paper['MedlineCitation']['Article']['ArticleTitle']
        
            if paper['MedlineCitation']['KeywordList']:
                for k in paper['MedlineCitation']['KeywordList'][0]:
                    klist=klist+k+' '
                klist = klist.split(' ')[:-1]
            else:
                klist = []
    
            for t in paper['MedlineCitation']['Article']['Abstract']['AbstractText']:
                abstract+=t
    
            df = pd.DataFrame({'pmid':pmid,'title':title,'key words':[klist],'abstract':abstract})
        
            df_fin = df_fin.append(df,ignore_index=True)
    
    df_fin['Label'] = label
    return df_fin

# %%
DAE = ['Drug Related Side Effects and Adverse Reactions',
'Side Effects of Drugs',
'Drug Side Effects',
'Drug Side Effect',
'Effects, Drug Side',
'Side Effect, Drug',
'Side Effects, Drug',
'Adverse Drug Reaction',
'Adverse Drug Reactions',
'Drug Reaction, Adverse',
'Drug Reactions, Adverse',
'Reactions, Adverse Drug',
'Adverse Drug Event',
'Adverse Drug Events',
'Drug Event, Adverse',
'Drug Events, Adverse',
'Drug Toxicity',
'Toxicity, Drug',
'Drug Toxicities',
'Toxicities, Drug']

CA = ['Abnormality, Congenital',
'Congenital Abnormality',
'Deformities',
'Deformity',
'Congenital Defects',
'Congenital Defect',
'Defect, Congenital',
'Defects, Congenital',
'Abnormalities, Congenital',
'Birth Defects',
'Birth Defect',
'Defect, Birth',
'Fetal Malformations',
'Fetal Malformation',
'Malformation, Fetal',
'Fetal Anomalies',
'Anomaly, Fetal',
'Fetal Anomaly']

# %%
def label_search(lst,label):
    df_lst = [] 
    for q in lst:
        df_lst.append(create_df(q,label))
    df = pd.concat(df_lst,ignore_index=True)
    return df

# %%
df_DAE = label_search(DAE,'Drug adverse events')

# %%
df_CA = label_search(CA,'Congenital anomalies')

# %%
df_DAE.drop_duplicates(subset='pmid',keep='first',inplace=True)
df_CA.drop_duplicates(subset='pmid',keep='first',inplace=True)

# %%
OTHER = ['latest','virus','disease','anomalies','deficiency','hair']
df_OTH = label_search(OTHER,'Others')

# %%
df_OTH.drop_duplicates(subset='pmid',keep='first',inplace=True)

# %%
df
# Out:
#           pmid                                              title  \
# 0     32808142  Latest Generation High-Definition Colonoscopy ...
# 1     33434275  Evaluation of automated cephalometric analysis...
# 2     32852869  Reproducibility and repeatability of identifyi...
# 3     33337279  Early Outcomes of Isolated Aortic Valve Replac...
# 4     32110605  Knowledge, attitude, and practice of general d...
# ...        ...                                                ...
# 5674  27106540  Hair Trace Elements are Associated with Increa...
# 5675  27560098  Perception of Hair Transplant for Androgenetic...
# 5676  28600869  Follow-up on the characterization of peptidic ...
# 5677  26884274  Sources of variation in hair cortisol in wild ...
# 5678  26776657  Suitability of hair type for dermatophytes per...
#
#                                               key words  \
# 0     [Adenomatous, polyps, Colonic, polyps, Colonos...
# 1     [Artificial, intelligence, Deep, learning, Mac...
# 2     [cardiac, resynchronization, therapy, coronary...
# 3     [Trifecta, valve, aortic, valve, replacement, ...
# 4     [Dental, dental, technology, knowledge, practice]
# ...                                                 ...
# 5674  [Boron, Goiter, Iodine, Schoolchildren, Silico...
# 5675                                                 []
# 5676                                                 []
# 5677  [Chronic, stress, Cortisol, Hair, cortisol, an...
# 5678  [cow, dermatophytes, hair, perforating, human,...
#
#                                                abstract   Label
# 0     Adenoma detection rate (ADR) is an important q...  Others
# 1     To compare an automated cephalometric analysis...  Others
# 2     Studies have shown an association between the ...  Others
# 3     The aim of this study is to evaluate early and...  Others
# 4     Choosing latest technology for the treatment i...  Others
# ...                                                 ...     ...
# 5674  The objective of the study was analysis of hai...  Others
# 5675  Hair transplant is among the most common cosme...  Others
# 5676  Species identification of hair is routinely do...  Others
# 5677  Hair cortisol analysis is a potentially powerf...  Others
# 5678  Most of the dermatophyte species have the abil...  Others
#
# [5677 rows x 5 columns]

# %%
CA_DE = ['Congenital anomalies caused by drug usage',
        'Drug-Related Side Effects and Adverse Reactions/congenital[Mesh]',
        'Congenital Abnormalities/adverse effects[Mesh] OR Congenital Abnormalities/drug effects[Mesh]',
        '(Congenital Abnormalities) AND (Drug effects)',
        'drug reaction congenital',
        'Congenital Abnormalities by drug effects']
df_CADE = label_search(CA_DE,'congenital anomalies caused by drug usage')

# %%
df_CADE.drop_duplicates(subset='pmid',keep='first',inplace=True)

# %%
df_merge = pd.merge(df_DAE,df_CA,left_on=['pmid','title','abstract'],right_on=['pmid','title','abstract'],how='inner')
df_merge.drop(['key words_x','Label_x'],axis=1,inplace=True)
df_merge.rename(columns={"key words_y": "key words", "Label_y": "Label"},inplace=True)

# %%
df_merge
# Out:
#        pmid                                              title  \
# 0  26017034  P-Glycoprotein-Mediated Drug Interactions in P...
#
#                                             abstract key words  \
# 0  Drug use in pregnancy is very common but may c...        []
#
#                   Label
# 0  Congenital anomalies

# %%
df_CADE[df_CADE['pmid']=='26017034']
# Out:
#          pmid                                              title key words  \
# 177  26017034  P-Glycoprotein-Mediated Drug Interactions in P...        []
#
#                                               abstract  \
# 177  Drug use in pregnancy is very common but may c...
#
#                                          Label
# 177  congenital anomalies caused by drug usage

# %%
df_CA = df_CA[~(df_CA['pmid']=='26017034')]
df_DAE = df_DAE[~(df_DAE['pmid']=='26017034')]
df_OTH = df_OTH[~(df_OTH['pmid']=='26017034')]

# %% [markdown]
# #### Cheking redundancy in data

# %%
df_fin = pd.concat([df_CADE,df_CA,df_DAE,df_OTH]).drop_duplicates(subset=['pmid'],keep='first')

# %%
len(set(df_fin['pmid']))==len(set(df_fin['pmid']))
# Out:
# True

# %%
df_fin = df_fin.set_index('pmid')

# %%
print(df_CADE.shape,df_CA.shape,df_DAE.shape,df_OTH.shape)
# Out:
# (1794, 5) (4831, 5) (3474, 5) (5675, 5)

# %%
df_DAE.to_csv('DAE.csv',index=False)
df_CA.to_csv('CA.csv',index=False)
df_CADE.to_csv('CADE.csv',index=False)
df_OTH.to_csv('OTH.csv',index=False)

# %%
df_fin.to_csv('data.csv')
